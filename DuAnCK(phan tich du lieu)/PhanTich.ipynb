# %%
import os

# Specify the directory path
directory_path = './Brno University of Technology Smartphone PPG Database (BUT PPG) v2.0.0/brno-university-of-technology-smartphone-ppg-database-but-ppg-2.0.0/112066'

# List all files and subdirectories in the directory
items = os.listdir(directory_path)

# Print the items
for item in items:
    print(item)
# Out:
# 112066.qrs
# 112066_ACC.dat
# 112066_ACC.hea
# 112066_ECG.dat
# 112066_ECG.hea
# 112066_PPG.dat
# 112066_PPG.hea

# %%
# !pip install numpy scipy pandas matplotlib wfdb scikit-learn tensorflow
# Out:
# Requirement already satisfied: numpy in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (2.0.2)
# Requirement already satisfied: scipy in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (1.13.1)
# Requirement already satisfied: pandas in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (3.9.4)
# Requirement already satisfied: wfdb in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (4.2.0)
# Requirement already satisfied: scikit-learn in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (1.6.0)
# Requirement already satisfied: tensorflow in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (2.18.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: requests>=2.8.1 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from wfdb) (2.32.3)
# Requirement already satisfied: soundfile>=0.10.0 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from wfdb) (0.13.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (25.1.21)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (5.29.3)
# Requirement already satisfied: setuptools in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (49.2.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.69.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.31.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.8.1->wfdb) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.8.1->wfdb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.8.1->wfdb) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.8.1->wfdb) (2024.12.14)
# Requirement already satisfied: cffi>=1.0 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from soundfile>=0.10.0->wfdb) (1.17.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.45.1)
# Requirement already satisfied: pycparser in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from cffi>=1.0->soundfile>=0.10.0->wfdb) (2.22)
# Requirement already satisfied: rich in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.14.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.1.3)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from markdown>=2.6.8->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (8.5.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\phanv\appdata\local\programs\python\python39\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.2)

# %%
import wfdb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data_path = './Brno University of Technology Smartphone PPG Database (BUT PPG) v2.0.0/brno-university-of-technology-smartphone-ppg-database-but-ppg-2.0.0/'
record_name = '112066'
record_path = os.path.join(data_path, record_name)  # Sử dụng os.path.join để đảm bảo đường dẫn đúng

print(record_path)
# Out:
# ./Brno University of Technology Smartphone PPG Database (BUT PPG) v2.0.0/brno-university-of-technology-smartphone-ppg-database-but-ppg-2.0.0/112066

# %%
import os

# Kiểm tra thư mục
if os.path.exists(data_path):
    print("Thư mục dữ liệu tồn tại.")
    # Liệt kê các tệp tin
    files = os.listdir(data_path)
    print(f"Có {len(files)} tệp tin trong thư mục dữ liệu.")
    print(files[:10])  # In 10 tệp đầu tiên
else:
    print("Thư mục dữ liệu không tồn tại. Vui lòng kiểm tra lại đường dẫn.")
# Out:
# Thư mục dữ liệu tồn tại.
# Có 3894 tệp tin trong thư mục dữ liệu.
# ['100001', '100002', '100003', '100004', '101001', '101002', '101003', '101004', '102001', '102002']

# %%
import os

# Đường dẫn đến thư mục con chứa dữ liệu
data_path = record_path

# Kiểm tra thư mục con
if os.path.exists(data_path):
    print("Thư mục con chứa dữ liệu tồn tại.")
    # Liệt kê các tệp tin trong thư mục con
    files = os.listdir(data_path)
    print(f"Có {len(files)} tệp tin trong thư mục con dữ liệu.")
    print(files[:10])  # In 10 tệp đầu tiên
else:
    print("Thư mục con dữ liệu không tồn tại. Vui lòng kiểm tra lại đường dẫn.")
# Out:
# Thư mục con chứa dữ liệu tồn tại.
# Có 7 tệp tin trong thư mục con dữ liệu.
# ['112066.qrs', '112066_ACC.dat', '112066_ACC.hea', '112066_ECG.dat', '112066_ECG.hea', '112066_PPG.dat', '112066_PPG.hea']

# %%
# Liệt kê tất cả các tệp tin trong thư mục con
files = os.listdir(data_path)
print("Các tệp tin trong thư mục con dữ liệu:")
for file in files:
    print(file)
# Out:
# Các tệp tin trong thư mục con dữ liệu:
# 112066.qrs
# 112066_ACC.dat
# 112066_ACC.hea
# 112066_ECG.dat
# 112066_ECG.hea
# 112066_PPG.dat
# 112066_PPG.hea

# %%
# Đọc tệp tiêu đề để kiểm tra tên các kênh
record_name = '112066_ACC'
record_path = os.path.join(data_path, record_name)
try:
    record_header = wfdb.rdheader(record_path)
    print("Tên các kênh trong bản ghi:")
    print(record_header.sig_name)
except FileNotFoundError as e:
    print(e)
    raise
# Out:
# Tên các kênh trong bản ghi:
# ['ACC_X', 'ACC_Y', 'ACC_Z']

# %%
import wfdb
import numpy as np
import matplotlib.pyplot as plt

# Đọc tín hiệu ACC
record_name = "112066_ACC"
record_path = os.path.join(data_path, record_name)
record = wfdb.rdrecord(record_path)  # Đọc file .dat và .hea

# Lấy dữ liệu của các trục
acc_x = record.p_signal[:, 0]  # Kênh 1 - ACC_X
acc_y = record.p_signal[:, 1]  # Kênh 2 - ACC_Y
acc_z = record.p_signal[:, 2]  # Kênh 3 - ACC_Z

# Tạo trục thời gian (dựa vào tần số lấy mẫu ACC, thường là 100 Hz)
fs = record.fs  # Tần số lấy mẫu
time = np.arange(len(acc_x)) / fs  # Thời gian tính bằng giây

# Vẽ biểu đồ 2D
plt.figure(figsize=(12, 5))
plt.plot(time, acc_x, label="ACC_X", color="r")
plt.plot(time, acc_y, label="ACC_Y", color="g")
plt.plot(time, acc_z, label="ACC_Z", color="b")
plt.xlabel("Time (s)")
plt.ylabel("Acceleration")
plt.title("Accelerometer Data (ACC_X, ACC_Y, ACC_Z)")
plt.legend()
plt.grid()
plt.show()


from mpl_toolkits.mplot3d import Axes3D

# Vẽ quỹ đạo trong không gian 3D
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

ax.plot(acc_x, acc_y, acc_z, label='ACC Trajectory', color='purple')

ax.set_xlabel("ACC_X")
ax.set_ylabel("ACC_Y")
ax.set_zlabel("ACC_Z")
ax.set_title("3D Accelerometer Trajectory")
ax.legend()
plt.show()

# %%
# Đọc tệp tiêu đề để kiểm tra tên các kênh
record_name = '112066_ECG'
record_path = os.path.join(data_path, record_name)
try:
    record_header = wfdb.rdheader(record_path)
    print("Tên các kênh trong bản ghi:")
    print(record_header.sig_name)
except FileNotFoundError as e:
    print(e)
    raise
# Out:
# Tên các kênh trong bản ghi:
# ['ECG']

# %%
import wfdb
import numpy as np
import matplotlib.pyplot as plt

# Đọc tín hiệu ACC
record_name = '112066_ECG'
record_path = os.path.join(data_path, record_name)
record = wfdb.rdrecord(record_path)  # Đọc file .dat và .hea

# Lấy dữ liệu của các trục
ecg = record.p_signal[:, 0]  # Kênh 1 - ACC_X

fs = record.fs  # Tần số lấy mẫu
time = np.arange(len(acc_x)) / fs  # Thời gian tính bằng giây

# Vẽ biểu đồ 2D
plt.figure(figsize=(12, 5))
plt.plot(time, ecg, label="ECG", color="r")
plt.xlabel("Time (s)")
plt.ylabel("ECG Signal")
plt.title("ECG Signal")
plt.legend()
plt.grid()
plt.show()

# %%
# Đọc tệp tiêu đề để kiểm tra tên các kênh
record_name = '112066_PPG'
record_path = os.path.join(data_path, record_name)
try:
    record_header = wfdb.rdheader(record_path)
    print("Tên các kênh trong bản ghi:")
    print(record_header.sig_name)
except FileNotFoundError as e:
    print(e)
    raise
# Out:
# Tên các kênh trong bản ghi:
# ['.u. 0 0 27361 -30411 0 PPG_R', '.u. 0 0 23938 13904 0 PPG_G', '.u. 0 0 26931 -23776 0 PPG_B']

# %%
import wfdb
import numpy as np
import matplotlib.pyplot as plt

# Đọc dữ liệu từ tệp PPG
record_name = '112066_PPG'
record_path = os.path.join(data_path, record_name)
record = wfdb.rdrecord(record_path)

# Lấy dữ liệu từ ba kênh PPG (R, G, B)
ppg_r = record.p_signal[:, 0]  # Kênh PPG_R (Red)
ppg_g = record.p_signal[:, 1]  # Kênh PPG_G (Green)
ppg_b = record.p_signal[:, 2]  # Kênh PPG_B (Blue)

# Tần số lấy mẫu (sampling rate)
fs = record.fs
time = np.arange(len(ppg_r)) / fs  # Thời gian tính bằng giây

# Vẽ các tín hiệu PPG từ ba kênh
plt.figure(figsize=(12, 6))
plt.plot(time, ppg_r, label="PPG Red (R)", color="r")
plt.plot(time, ppg_g, label="PPG Green (G)", color="g")
plt.plot(time, ppg_b, label="PPG Blue (B)", color="b")
plt.xlabel("Time (s)")
plt.ylabel("PPG Signal")
plt.title("PPG Signal from Red, Green, and Blue Channels")
plt.legend()
plt.grid()
plt.show()
